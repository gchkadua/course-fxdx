# %% [markdown]
# 1. რა არის კლასტერირება?
# 2. კლასტერირების ტიპები
# 3. რა არის k-means კლასტერირება
# 4. როგორ მუშაობს k-means კლასტერირების ალგორითმი
# 5. k-means პითონში

# %% [markdown]
# კლასტერირება არის მონაცემების ჯგუფებად დაყოფის პროცესი, სადაც ეს ჯგუფები შეიცავს მსგავს მონაცემებს (data-points)
#
# მონაცემები თითოეულ ჯგუფში მაქსიმალურად მსგავსია, და განსხვავებულ ჯგუფებში შესაბამისად არამსგავსი.
#
# კლასტერირება არის unsupervized ML ტექნიკა.

# %% [markdown]
# ექსკლუზიური კლასტერირება: მონაცემები ექსკლუზიურად ეკუთვნიან ერთ კლასტერს მაგ k-means

# %% [markdown]
# ![clustered.webp](attachment:clustered.webp)

# %% [markdown]
# თანაკვეთი კლასტერირება: მონაცემები ეკუთვნიან რამოდენიმე კლასტერ კლასტერს მაგ C-means

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# იერარქიული კლასტერირება: როდესაც კლასტერები შეიცავს ქვეკლსტერების, ამის კარგი მაგალითია დენდოგრამა:

# %% [markdown]
# ![clustering.png](attachment:clustering.png)

# %% [markdown]
# k-means კლასტერირების ალგორითმის ალგორითმის მთავარი მიზანია დააჯგუფოს მსგავსი ელემენტები კლასტერებად.
#
# შენიშვნა: k k-menas  ალგორითმში აღნიშნავს კლასტერების რაოდენობას.

# %% [markdown]
# მარტივ მაგალითზე ვნახოთ როგორ მუშაობს k-means ალგორითმი

# %% [markdown]
# ![Screenshot%202022-01-05%20125018.png](attachment:Screenshot%202022-01-05%20125018.png)

# %% [markdown]
# 1.ავარჩიოთ კლასტერების რაოდენობა რაც გვინდა რომ ალგორითმა იპოვოს.
#   მაგ. ამ შემთხვევაში ავიღოთ k=3.

# %% [markdown]
# 2. რანდომულად ავარჩიოთ 3 ელემენტი ჩვენი მონაცემებიდან:

# %% [markdown]
# ![Screenshot%202022-01-05%20125504.png](attachment:Screenshot%202022-01-05%20125504.png)

# %% [markdown]
# ეს წერტილები არის ცვენი დაშვება რომ ისინი არიან ცენტროიდები კლასტრების.

# %% [markdown]
# 3.გავზომოთ მანძილი, პირველ წერტილსა და 3 კლასტერს შორის:

# %% [markdown]
# ![Screenshot%202022-01-05%20125839.png](attachment:Screenshot%202022-01-05%20125839.png)

# %% [markdown]
# 4.მივანიჭოთ პირველი წერტილი უახლოეს კლასტერს:

# %% [markdown]
# ![Screenshot%202022-01-05%20130102.png](attachment:Screenshot%202022-01-05%20130102.png)

# %% [markdown]
# 5.დავთვალოთ საშუალო წითელი კლასტერისთვის ახალი წერტილის გათვალისწინებით:

# %% [markdown]
# ![Screenshot%202022-01-05%20130454.png](attachment:Screenshot%202022-01-05%20130454.png)

# %% [markdown]
# ეხლა გავარკვიოთ თუ რომელ კლასტერს მიეკუთვნება მეორე ელემენტი.
#
# ამის გასაკეთებლად გამოვიყენოთ იგივე პრცედურა რაც პირველი წერტილის შემთხვევაში იყო, იმ განსხვავებით რომ, წლითელ კლასტერთან მანძილის გასაზომად გავზომავთ მანძილს საშუალოსთან(წითელი ხაზი)

# %% [markdown]
# ![Screenshot%202022-01-05%20131013.png](attachment:Screenshot%202022-01-05%20131013.png)

# %% [markdown]
# ![Screenshot%202022-01-05%20131127.png](attachment:Screenshot%202022-01-05%20131127.png)

# %% [markdown]
# ეხლა გავარკვიოთ რომელ კლასტერს მიეკუთვნება მეხუთე წერტილი, და შემდგომი ელემენტები:

# %% [markdown]
# ![Screenshot%202022-01-05%20131226.png](attachment:Screenshot%202022-01-05%20131226.png)

# %% [markdown]
# ![Screenshot%202022-01-05%20131644.png](attachment:Screenshot%202022-01-05%20131644.png)

# %% [markdown]
# მიღებული შედეგი შევადაროთ იმას თუ რაც უნდა მიგვეღო:

# %% [markdown]
# ![Screenshot%202022-01-05%20131824.png](attachment:Screenshot%202022-01-05%20131824.png)

# %% [markdown]
# როგორც ცანს ძალიან ცუდი შედეგი მივიღედთ. გასაუმჯობესებლად მოვახდინოთ მეორე იტერაცია. მეორე იტერაციაზე ყველაფერი დაიწყება თავიდან ანალოგიურად, განსხვავება იქნება მხოლოდ ის რომ, რანდომად არჩეული საწყისი სამი ელემენტი იქნება განსხვავებული. ხოლო საუკეთესო იტერაცია იქნება შერჩეული კლასტერების საშუალოების ჯამის მინიმუმით, რაც ვარიაციის შემცირებას ნიშნავს.

# %% [markdown]
# ![Screenshot%202022-01-05%20132326.png](attachment:Screenshot%202022-01-05%20132326.png)

# %% [markdown]
# მრავალ განზომილების შემთხვევაშიც იქნება ანალოგიურად, განსხვავებით მანძილი წერტილებს შორის დაითვლება შესაბამისი განზომილების მეტრიკით.

# %% [markdown]
# ![Screenshot%202022-01-05%20132810.png](attachment:Screenshot%202022-01-05%20132810.png)

# %% [markdown]
# მნიშვნელოვანი კითხვა: როგორ ავარჩიოთ k-ს ანუ კლასტერების რაოდენობა.

# %% [markdown]
# ![Screenshot%202022-01-05%20144759.png](attachment:Screenshot%202022-01-05%20144759.png)

# %% [markdown]
# "იდაყვის მეთოდი":

# %% [markdown]
# ![Screenshot%202022-01-05%20144844.png](attachment:Screenshot%202022-01-05%20144844.png)

# %% [markdown]
# k-means კლასტერიზაციის ალგორითმი:
# რანდომულად შევარჩიოთ k ელემენტი მონაცმეებიდან როგორც საწყისი ცენტროიდები:
# სანამ მართალია:
#      შეიქმნას k რაოდენობის კლასტერი ელემენტების უახლოეს ცენტროიდთან მდებარეობის მიხედვით
#      დაიტვალოს ახალი k ცენტროიდი თითოეულ კლასტერში ელემენტების მანძილბის გასაშუალოებით.
#      თუ ცენტროიდები არ იცვლება:
#      დასრულდეს პროცესი.

# %% [markdown]
# მოდით ხელით დავწეროთ ეს ალგორითმი და შემდგომ პითონის mL ბიბლიოთეკების გამოყენებით მოვახდინოთ იგივეს გამეორება.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.DataFrame({
    'x' :[12,20,28,18,29,33,24,45,45,52,51,52,55,53,55,61,65,69,72],
    'y' :[39,36,30,52,54,46,55,59,63,70,66,53,58,23,14,8,19,7,24]
})

# %%
df.head()
# Out:
#     x   y
# 0  12  39
# 1  20  36
# 2  28  30
# 3  18  52
# 4  29  54

# %%
np.random.seed(100)
k=3

# %%
centroids={
    i+1 : [np.random.randint(0,80), np.random.randint(0,80)]
    for i in range(k)
}
fig = plt.figure(figsize=(5,5))
plt.scatter(df['x'],df['y'], color='k')
colmap={1: 'r', 2: 'g', 3: 'b'}
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,80)
plt.ylim(0,80)
plt.show()

# %%
def assignment(df, centroids):
    for i in centroids.keys():
        df['distance_from_{}'.format(i)]= (
             np.sqrt(
                 (df['x']-centroids[i][0])**2
                 +(df['y']-centroids[i][1])**2
             ) 
        )
    centroid_distance_cols = ['distance_from_{}'.format(i) for i in centroids.keys()]
    df['closest'] = df.loc[:, centroid_distance_cols].idxmin(axis=1)
    df['closest']= df['closest'].map(lambda x: int(x.lstrip('distance_from_')))
    df['color']=df['closest'].map(lambda x: colmap[x]) 
    return df

# %%
df=assignment(df,centroids)

# %%
df.head()
# Out:
#     x   y  distance_from_1  distance_from_2  distance_from_3  closest color
# 0  12  39        15.524175        68.007353        46.227697        1     r
# 1  20  36        16.970563        63.702433        38.209946        1     r
# 2  28  30        20.880613        62.625873        28.284271        1     r
# 3  18  52        29.732137        55.946403        51.613952        1     r
# 4  29  54        36.619667        45.486262        47.927028        1     r

# %%
fig = plt.figure(figsize=(5,5))
plt.scatter(df['x'],df['y'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,80)
plt.ylim(0,80)
plt.show()

# %%
import copy
old_centroids=copy.deepcopy(centroids)

def update(k):
    for i in centroids.keys():
        centroids[i][0]=np.mean(df[df['closest']==i]['x'])
        centroids[i][1]=np.mean(df[df['closest']==i]['y'])
    return k
centroids=update(centroids)

# %%
fig = plt.figure(figsize=(5,5))
ax=plt.axes()
plt.scatter(df['x'],df['y'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,80)
plt.ylim(0,80)
for i in old_centroids.keys(): 
    old_x=old_centroids[i][0]
    old_y=old_centroids[i][1]
    dx=(centroids[i][0]-old_centroids[i][0])*0.75
    dy=(centroids[i][1]-old_centroids[i][1])*0.75
    ax.arrow(old_x,old_y,dx,dy, head_width=2, head_length=3, fc=colmap[i], ec=colmap[i])
plt.show()

# %%
df=assignment(df,centroids)

# %%
fig = plt.figure(figsize=(5,5))
plt.scatter(df['x'],df['y'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])
plt.xlim(0,80)
plt.ylim(0,80)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
lables=kmeans.predict(df)
centroids=kmeans.cluster_centers_

# %%
fig = plt.figure(figsize=(5,5))
colors=map(lambda x: colmap[x+1], lables)
colors1=list(colors)
plt.scatter(df['x'],df['y'], color=colors1, alpha=0.5, edgecolor='k')
for idx, centroid in enumerate(centroids):
    plt.scatter(*centroid, color=colmap[idx+1])
plt.xlim(0,80)
plt.ylim(0,80)
plt.show()

# %% [markdown]
# ეხლა გავიხილოთ მაგალითი რომელშიც გამოვიყენებთ კლასტერირების ბიბლიოთეკას და იდაყვის მეთოდს

# %%
dataset = pd.read_csv('Mall_Customers.csv',index_col='CustomerID')

# %%
dataset.head()
# Out:
#              Genre  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Genre                   200 non-null    object
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB

# %%
dataset.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
dataset.isnull().sum()
# Out:
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
dataset.shape
# Out:
# (200, 4)

# %%
dataset.drop_duplicates(inplace=True)

# %%
#ხარჯვის და შემოსავლის სვეტები გამოვიყენოთ მარტივი ვიზუალიზაციისთვის
X = dataset.iloc[:, [2, 3]].values

# %%
#იდაყვის მეთოდით ვიპოვოთ კლასტერების რაოდენობა

from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    # inertia method returns wcss for that model
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\George Ch\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
plt.figure(figsize=(10,5))
sns.lineplot(range(1, 11), wcss,marker='o',color='red')
plt.title('იდაყვის მეთოდი')
plt.xlabel('კლასტერების რაოდენობა')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\George Ch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], color = 'yellow', label = 'Cluster 1',s=50)
sns.scatterplot(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], color = 'blue', label = 'Cluster 2',s=50)
sns.scatterplot(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], color = 'green', label = 'Cluster 3',s=50)
sns.scatterplot(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], color = 'grey', label = 'Cluster 4',s=50)
sns.scatterplot(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], color = 'orange', label = 'Cluster 5',s=50)
sns.scatterplot(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'red', 
                label = 'Centroids',s=300,marker=',')
plt.grid(False)
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
